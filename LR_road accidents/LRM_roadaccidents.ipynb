# %%
import pandas as pd
import numpy as np

# %%
#import data and prepare
data = pd.read_csv('C:/Users/user/Documents/Y2S2/LR_road accidents/caraccidents.csv')
data.head(4)
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# ...

# %%
data['Time'] = data['Time'].astype('category')
data['Time'] = data['Time'].cat.codes

# %%
data
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0       420      Monday              18-30          Male   Above high school
# 1       420      Monday              31-50          Male  Junior high school
# 2       420      Monday              18-30          Male  Junior high school
# 3       594      Sunday              18-30          Male  Junior high school
# 4       594      Sunday              18-30          Male  Junior high school
# ...     ...         ...                ...           ...                 ...
# 12311   374   Wednesday              31-50          Male                 NaN
# 12312   476      Sunday            Unknown          Male   Elementary school
# 12313   246      Sunday            Over 51          Male  Junior high school
# 12314   246      Sunday              18-30        Female  Junior high school
# 12315   246      Sunday              18-30          Male  Junior high school
#
# ...

# %%
data['Day_of_week'] = data['Day_of_week'].astype('category')
data['Day_of_week'] = data['Day_of_week'].cat.codes
data
# Out:
#        Time  Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0       420            1              18-30          Male   Above high school
# 1       420            1              31-50          Male  Junior high school
# 2       420            1              18-30          Male  Junior high school
# 3       594            3              18-30          Male  Junior high school
# 4       594            3              18-30          Male  Junior high school
# ...     ...          ...                ...           ...                 ...
# 12311   374            6              31-50          Male                 NaN
# 12312   476            3            Unknown          Male   Elementary school
# 12313   246            3            Over 51          Male  Junior high school
# 12314   246            3              18-30        Female  Junior high school
# 12315   246            3              18-30          Male  Junior high school
#
# ...

# %%
data['Age_band_of_driver'] = data['Age_band_of_driver'].astype('category')
data['Age_band_of_driver'] = data['Age_band_of_driver'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver Sex_of_driver  \
# 0       420            1                   0          Male
# 1       420            1                   1          Male
# 2       420            1                   0          Male
# 3       594            3                   0          Male
# 4       594            3                   0          Male
# ...     ...          ...                 ...           ...
# 12311   374            6                   1          Male
# 12312   476            3                   4          Male
# 12313   246            3                   2          Male
# 12314   246            3                   0        Female
# 12315   246            3                   0          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
data['Sex_of_driver'] = data['Sex_of_driver'].astype('category')
data['Sex_of_driver'] = data['Sex_of_driver'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
data['Educational_level'] = data['Educational_level'].astype('category')
data['Educational_level'] = data['Educational_level'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 0                      0                Employee              1-2yr
# 1                      4                Employee         Above 10yr
# ...

# %%
data['Vehicle_driver_relation'] = data['Vehicle_driver_relation'].astype('category')
data['Vehicle_driver_relation'] = data['Vehicle_driver_relation'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation Driving_experience  \
# 0                      0                        0              1-2yr
# 1                      4                        0         Above 10yr
# ...

# %%
data['Driving_experience'] = data['Driving_experience'].astype('category')
data['Driving_experience'] = data['Driving_experience'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Type_of_vehicle'] = data['Type_of_vehicle'].astype('category')
data['Type_of_vehicle'] = data['Type_of_vehicle'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Owner_of_vehicle'] = data['Owner_of_vehicle'].astype('category')
data['Owner_of_vehicle'] = data['Owner_of_vehicle'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Service_year_of_vehicle'] = data['Service_year_of_vehicle'].astype('category')
data['Service_year_of_vehicle'] = data['Service_year_of_vehicle'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Casualty_class'] = data['Casualty_class'].astype('category')
data['Casualty_class'] = data['Casualty_class'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Sex_of_casualty'] = data['Sex_of_casualty'].astype('category')
data['Sex_of_casualty'] = data['Sex_of_casualty'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Age_band_of_casualty'] = data['Age_band_of_casualty'].astype('category')
data['Age_band_of_casualty'] = data['Age_band_of_casualty'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Casualty_severity'] = data['Casualty_severity'].astype('category')
data['Casualty_severity'] = data['Casualty_severity'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Work_of_casuality'] = data['Work_of_casuality'].astype('category')
data['Work_of_casuality'] = data['Work_of_casuality'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Fitness_of_casuality'] = data['Fitness_of_casuality'].astype('category')
data['Fitness_of_casuality'] = data['Fitness_of_casuality'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Pedestrian_movement'] = data['Pedestrian_movement'].astype('category')
data['Pedestrian_movement'] = data['Pedestrian_movement'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Cause_of_accident'] = data['Cause_of_accident'].astype('category')
data['Cause_of_accident'] = data['Cause_of_accident'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Accident_severity'] = data['Accident_severity'].astype('category')
data['Accident_severity'] = data['Accident_severity'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Service_year_of_vehicle           0
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
data['Defect_of_vehicle'] = data['Defect_of_vehicle'].astype('category')
data['Defect_of_vehicle'] = data['Defect_of_vehicle'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Area_accident_occured'] = data['Area_accident_occured'].astype('category')
data['Area_accident_occured'] = data['Area_accident_occured'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Lanes_or_Medians'] = data['Lanes_or_Medians'].astype('category')
data['Lanes_or_Medians'] = data['Lanes_or_Medians'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Road_allignment'] = data['Road_allignment'].astype('category')
data['Road_allignment'] = data['Road_allignment'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Types_of_Junction'] = data['Types_of_Junction'].astype('category')
data['Types_of_Junction'] = data['Types_of_Junction'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Road_surface_type'] = data['Road_surface_type'].astype('category')
data['Road_surface_type'] = data['Road_surface_type'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Type_of_collision'] = data['Type_of_collision'].astype('category')
data['Type_of_collision'] = data['Type_of_collision'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Vehicle_movement'] = data['Vehicle_movement'].astype('category')
data['Vehicle_movement'] = data['Vehicle_movement'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
data['Road_surface_conditions'] = data['Road_surface_conditions'].astype('category')
data['Road_surface_conditions'] = data['Road_surface_conditions'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
data['Weather_conditions'] = data['Weather_conditions'].astype('category')
data['Weather_conditions'] = data['Weather_conditions'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
#define x
x = data.drop(columns = 'Accident_severity')
x
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data['Light_conditions'] = data['Light_conditions'].astype('category')
data['Light_conditions'] = data['Light_conditions'].cat.codes
data
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 0       420            1                   0              1
# 1       420            1                   1              1
# 2       420            1                   0              1
# 3       594            3                   0              1
# 4       594            3                   0              1
# ...     ...          ...                 ...            ...
# 12311   374            6                   1              1
# 12312   476            3                   4              1
# 12313   246            3                   2              1
# 12314   246            3                   0              0
# 12315   246            3                   0              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 0                      0                        0                   0
# 1                      4                        0                   3
# ...

# %%
data.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# #Identifying ouliers

# %%
data.describe()
# Out:
#                Time   Day_of_week  Age_band_of_driver  Sex_of_driver  \
# count  12316.000000  12316.000000        12316.000000   12316.000000
# mean     504.737090      2.980513            1.292952       0.957535
# std      293.164211      2.059712            1.337520       0.263767
# min        0.000000      0.000000            0.000000       0.000000
# 25%      280.000000      1.000000            0.000000       1.000000
# 50%      463.000000      3.000000            1.000000       1.000000
# 75%      711.250000      5.000000            2.000000       1.000000
# max     1073.000000      6.000000            4.000000       2.000000
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# count       12316.000000             12316.000000        12316.000000
# mean            2.907519                 0.286781            1.741799
# std             1.670689                 0.791094            1.438887
# ...

# %%
import seaborn as sns
sns.displot(data['Time'])

# %%
#to see outliers clearly
sns.boxplot(data['Time'])
# Out:
# <Axes: >

# %%
sns.displot(data['Accident_severity'])

# %%
#to see outliers clearly
sns.boxplot(data['Accident_severity'])
# Out:
# <Axes: >

# %% [markdown]
# #capping - change the outlier values to upper (or) lower limit values.

# %%
upper_limit= data['Accident_severity'].mean() + 3*data['Accident_severity'].std()
lower_limit= data['Accident_severity'].mean() - 3*data['Accident_severity'].std()
print('upper limit;', upper_limit)
print('lower limit;',lower_limit)
# Out:
# upper limit; 3.0510648320118205
# lower limit; 0.6145733622070815

# %%
#find the ouliers
data.loc[(data['Accident_severity']> upper_limit) | (data['Accident_severity']<lower_limit)]
# Out:
#        Time  Day_of_week  Age_band_of_driver  Sex_of_driver  \
# 89      323            3                   1              1
# 90      323            3                   1              1
# 453     619            6                   2              1
# 523     394            4                   1              1
# 524     394            4                   0              1
# ...     ...          ...                 ...            ...
# 12262   388            5                   1              1
# 12268   508            5                   1              1
# 12269   508            5                   2              1
# 12270   511            2                   1              1
# 12271   511            2                   1              1
#
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 89                     4                        0                   2
# 90                     4                        0                   3
# ...

# %%
#trimming - delete the outlier data
new_data = data.loc[(data['Accident_severity']< upper_limit) | (data['Accident_severity']>lower_limit)]
print('old data:', len(data))
print('new data:',len(new_data))
# Out:
# old data: 12316
# new data: 12316

# %%
#define y
y = data['Accident_severity']

# %%
# split the dataset into training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#train the model on the training set
from sklearn.linear_model import LinearRegression
# Fit the model on the training set
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c = model.intercept_

# %%
c
# Out:
# 1.701089171019583

# %%
m = model.coef_
m
# Out:
# array([-3.14980457e-05, -1.43493381e-03,  6.08516583e-03,  1.96381568e-02,
#         4.25623194e-04, -3.66432421e-03,  1.32287158e-03, -7.06401245e-04,
#        -3.42988862e-03, -1.08585107e-03, -3.31150573e-03, -2.67402366e-03,
#        -2.96744466e-03, -1.58555039e-03,  1.52919736e-04, -5.76510380e-04,
#         6.26649053e-03,  6.36397187e-03,  4.47091006e-03,  4.19589380e-03,
#         6.79777895e-02, -2.60386858e-02, -6.85565196e-04, -3.74845030e-03,
#        -1.77893594e-02,  1.26677194e-02, -8.75629696e-03,  3.61745491e-03,
#        -3.46631407e-03,  6.69480617e-03,  6.51621654e-04])

# %%
y_pred_train = model.predict(x_train)

# %%
y_pred_train
# Out:
# array([1.80593406, 1.88503282, 1.79420246, ..., 1.77293439, 1.84831016,
#        1.91052051])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train,y_pred_train)
plt.xlabel('actual Accident_severity')
plt.ylabel('Predicted Accident_severity')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.019721915167462467

# %%
y_pred_test = model.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred_test)
plt.xlabel('actual Accident_severity')
plt.ylabel('Predicted Accident_severity')
plt.show()

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.011601704364864851

# %%
# contains outliers
